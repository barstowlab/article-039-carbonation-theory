# %%
# Code to modify the log K values in the CO2min database entry 

from CO2min import * 

CO2min_logKeq(1) # Set the CO2 partial pressure to 1 bar

# %%
# Test and Run the 3 Interval Stitch Function 

from Three_Interval_Stitch_NaOH_Matched import * 

# Set the Temperature & the Mineral Kinetics 
Temp(25)

# Run the CrunchTope model 
Model_Run, Magnesite_Volume_Fraction = Time_Series('PestControl.ant')

# Save the Time Series 
Model_Run.to_csv('100mM NaOH Treatment + CO2 Bubbling at 25°C.csv', index=False) 

# Calculate the Reaction Rate and the Carbonation Percent 
# uncomment the savefig code in function in order to save the figure 
Magnesium_Consumption_Rate, Carbonation_Percent = Magnesium_Rate(Model_Run)

print(Magnesium_Consumption_Rate)
print(Carbonation_Percent)
print(Magnesite_Volume_Fraction)

# Save the values 
Volume_Fraction_25 = Magnesite_Volume_Fraction
Reaction_Rate_25 = Magnesium_Consumption_Rate
Carbonation_Percent_25 = Carbonation_Percent
# Out:
# Acid depedence log of rate constant for magnesite is -6.3942
# Carbonate mechanism log of rate constant for magnesite is -5.22
# Neutral mechanism log of rate constant for magnesite is -9.3352
# Neutral mechanism log of rate constant for Quartz is -13.4025
# Neutral mechanism log of rate constant for Amorphous Silica is -12.229
# Magnesite line found at index 55: Magnesite            1.0e-10  specific_surface_area 0.1
# Modified line: Magnesite            9.8186516e-11  specific_surface_area 0.1
# Quartz line found at index 56: Quartz               1.0025259e-10  specific_surface_area 0.1
# Modified line: Quartz               1e-10  specific_surface_area 0.1
# Amorphous_silica line found at index 57: Amorphous_silica     1.0001621e-10  specific_surface_area 0.1
# Modified line: Amorphous_silica     1e-10  specific_surface_area 0.1
# Magnesite line found at index 55: Magnesite            0.00059166966  specific_surface_area 0.1
# Modified line: Magnesite            0.00067783722  specific_surface_area 0.1
# Quartz line found at index 56: Quartz               1.0024939999999999e-10  specific_surface_area 0.1
# Modified line: Quartz               1e-10  specific_surface_area 0.1
# Amorphous_silica line found at index 57: Amorphous_silica     9.9996346e-11  specific_surface_area 0.1
# Modified line: Amorphous_silica     1e-10  specific_surface_area 0.1
# Found Equilibrium
# Equilibrium Concentration: 0.00609195676007078
# Pattern found on line 29: spatial_profile       6.0
# Pattern found on line 29: spatial_profile       0.34567800000000004
# Percent Carbonation: 83.77989405322708%
# Time to reach equilibrium or end of experiment: 0.34567800000000004 hours
# Rate of change in Mg++ concentration: 0.07755647561654007 mol/kgw per hour
# 0.07755647561654007
# 83.77989405322708
# 0.060854701

# %%
# Test and Run the 3 Interval Stitch Function at 50 degrees Celsius 

from Three_Interval_Stitch_NaOH_Matched import * 

Temp(50)

Model_Run, Magnesite_Volume_Fraction = Time_Series('PestControl.ant')

Model_Run.to_csv('100mM NaOH Treatment and CO2 Bubbling at 50°C.csv', index=False) 

Magnesium_Consumption_Rate, Carbonation_Percent = Magnesium_Rate(Model_Run)

print(Magnesium_Consumption_Rate)
print(Carbonation_Percent)
print(Magnesite_Volume_Fraction)

Volume_Fraction_50 = Magnesite_Volume_Fraction
Reaction_Rate_50 = Magnesium_Consumption_Rate
Carbonation_Percent_50 = Carbonation_Percent
# Out:
# Acid depedence log of rate constant for magnesite is -6.1976
# Carbonate mechanism log of rate constant for magnesite is -4.3694
# Neutral mechanism log of rate constant for magnesite is -9.0167
# Neutral mechanism log of rate constant for Quartz is -12.1705
# Neutral mechanism log of rate constant for Amorphous Silica is -11.2192
# Magnesite line found at index 55: Magnesite            9.8186516e-11  specific_surface_area 0.1
# Modified line: Magnesite            3.9709119999999994e-11  specific_surface_area 0.1
# Quartz line found at index 56: Quartz               1e-10  specific_surface_area 0.1
# Modified line: Quartz               1.000001e-10  specific_surface_area 0.1
# Amorphous_silica line found at index 57: Amorphous_silica     1e-10  specific_surface_area 0.1
# Modified line: Amorphous_silica     1.0000003e-10  specific_surface_area 0.1
# Magnesite line found at index 55: Magnesite            0.00067783722  specific_surface_area 0.1
# Modified line: Magnesite            0.00082875501  specific_surface_area 0.1
# Quartz line found at index 56: Quartz               1e-10  specific_surface_area 0.1
# Modified line: Quartz               1.000002e-10  specific_surface_area 0.1
# Amorphous_silica line found at index 57: Amorphous_silica     1e-10  specific_surface_area 0.1
# Modified line: Amorphous_silica     1.0000006e-10  specific_surface_area 0.1
# Found Equilibrium
# Equilibrium Concentration: 0.00208365258243544
# Pattern found on line 29: spatial_profile       0.1
# Pattern found on line 29: spatial_profile       0.1113013
# Percent Carbonation: 95.22670831501237%
# Time to reach equilibrium or end of experiment: 0.1113013 hours
# Rate of change in Mg++ concentration: 0.2737842966393982 mol/kgw per hour
# 0.2737842966393982
# 95.22670831501237
# 0.072009811

# %%
# Test and Run the 3 Interval Stitch Function at 100 degrees Celsius 

from Three_Interval_Stitch_NaOH_Matched import * 

Temp(100)

Model_Run, Magnesite_Volume_Fraction = Time_Series('PestControl.ant')

Model_Run.to_csv('100mM NaOH Treatment and CO2 Bubbling at 100°C.csv', index=False) 

Magnesium_Consumption_Rate, Carbonation_Percent = Magnesium_Rate(Model_Run)

print(Magnesium_Consumption_Rate)
print(Carbonation_Percent)
print(Magnesite_Volume_Fraction)

Volume_Fraction_100 = Magnesite_Volume_Fraction
Reaction_Rate_100 = Magnesium_Consumption_Rate
Carbonation_Percent_100 = Carbonation_Percent
# Out:
# Acid depedence log of rate constant for magnesite is -5.8836
# Carbonate mechanism log of rate constant for magnesite is -3.0102
# Neutral mechanism log of rate constant for magnesite is -8.5078
# Neutral mechanism log of rate constant for Quartz is -10.2017
# Neutral mechanism log of rate constant for Amorphous Silica is -9.6057
# Magnesite line found at index 55: Magnesite            3.9709119999999994e-11  specific_surface_area 0.1
# Modified line: Magnesite            1.0e-10  specific_surface_area 0.1
# Quartz line found at index 56: Quartz               1.000001e-10  specific_surface_area 0.1
# Modified line: Quartz               1.0025259e-10  specific_surface_area 0.1
# Amorphous_silica line found at index 57: Amorphous_silica     1.0000003e-10  specific_surface_area 0.1
# Modified line: Amorphous_silica     1.0001621e-10  specific_surface_area 0.1
# Magnesite line found at index 55: Magnesite            0.00082875501  specific_surface_area 0.1
# Modified line: Magnesite            0.00059166966  specific_surface_area 0.1
# Quartz line found at index 56: Quartz               1.000002e-10  specific_surface_area 0.1
# Modified line: Quartz               1.0024939999999999e-10  specific_surface_area 0.1
# Amorphous_silica line found at index 57: Amorphous_silica     1.0000006e-10  specific_surface_area 0.1
# Modified line: Amorphous_silica     9.9996346e-11  specific_surface_area 0.1
# Found Equilibrium
# Equilibrium Concentration: 0.000362193875837169
# Pattern found on line 29: spatial_profile       6.0
# Pattern found on line 29: spatial_profile       2.96668
# Percent Carbonation: 97.92516355245212%
# Time to reach equilibrium or end of experiment: 2.96668 hours
# Rate of change in Mg++ concentration: 0.010562667300222903 mol/kgw per hour
# 0.010562667300222903
# 97.92516355245212
# 0.082560941

# %%
# Create the Three Bar Graphs for Volume Fraction, Reaction Rate, and Carbonation Percent 

from Three_Interval_Stitch_NaOH_Matched import * 

import pandas as pd 

Volume_Fractions = [Volume_Fraction_25, Volume_Fraction_50, Volume_Fraction_100]
Reaction_Rates = [Reaction_Rate_25, Reaction_Rate_50, Reaction_Rate_100]
Carbonation_Percentages = [Carbonation_Percent_25, Carbonation_Percent_50, Carbonation_Percent_100]


# Save Volume_Fractions to a CSV file
df_volume = pd.DataFrame({'Temperature (°C)': ['25°C', '50°C', '100°C'],
                           'Volume Fraction': Volume_Fractions})
df_volume.to_csv('Volume_Fractions.csv', index=False)

# Save Reaction_Rates to a CSV file
df_reaction = pd.DataFrame({'Temperature (°C)': ['25°C', '50°C', '100°C'],
                            'Reaction Rate': Reaction_Rates})
df_reaction.to_csv('Reaction_Rates.csv', index=False)

# Save Carbonation_Percentages to a CSV file
df_carbonation = pd.DataFrame({'Temperature (°C)': ['25°C', '50°C', '100°C'],
                               'Carbonation Percentage': Carbonation_Percentages})
df_carbonation.to_csv('Carbonation_Percentages.csv', index=False)

# File paths for the CSV files
volume_fractions_file = 'Volume_Fractions.csv'
reaction_rates_file = 'Reaction_Rates.csv'
carbonation_percentages_file = 'Carbonation_Percentages.csv'


# Create the Volume Fraction Bar Graph 
# uncomment code in the function to save the figure 

plot_bar_graph(volume_fractions_file, y_label='Magnesite Volume Fraction (m^3 mineral/m^3 porous medium)')

# Create the Reaction Rates Bar Graph

plot_bar_graph(reaction_rates_file, y_label=r'Reaction Rate (M hr$^{-1}$)')

# Create the Carbonation Percentage Bar Graph

plot_bar_graph(carbonation_percentages_file, y_label='Carbonation Percentage (%)')
# Out:
# /Users/tszkipeterwei/Desktop/MEng/MEngProject/Setup/ModelingMineralCarbonation/CrunchtopeModel/3 Time Interval Model NaOH Case/Three_Interval_Stitch_NaOH_Matched.py:1255: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Temperature (°C)', y=data.columns[1], data=data, palette="viridis")
