# %%
# Code to modify the log K values in the CO2min database entry 

from CO2min import * 

CO2min_logKeq(1)

# %%
# Test and Run the 3 Interval Stitch Function 

from Three_Interval_Stitch_Olivine_Modified import * 

# Set the Temperature & the Mineral Kinetics 
Temp(25)

# Run the CrunchTope Model 
Model_Run, Magnesite_Volume_Fraction, Forsterite_Volume_Fraction = Time_Series('PestControl.ant')

# Save the Time Series 
Model_Run.to_csv('Olivine Model at 25°C.csv', index=False) 

# Calculate the Reaction Rate & Carbonation Percent 
Magnesium_Consumption_Rate, Carbonation_Percent = Magnesium_Rate(Model_Run)

print(Magnesium_Consumption_Rate)
print(Carbonation_Percent)
print(Magnesite_Volume_Fraction)

# Save the Values 
Volume_Fraction_25 = Magnesite_Volume_Fraction
Reaction_Rate_25 = Magnesium_Consumption_Rate
Carbonation_Percent_25 = Carbonation_Percent
Forsterite_Fraction_25 = Forsterite_Volume_Fraction
# Out:
# Acid depedence log of rate constant for magnesite is -6.3942
# Carbonate mechanism log of rate constant for magnesite is -5.22
# Neutral mechanism log of rate constant for magnesite is -9.3352
# Neutral mechanism log of rate constant for Quartz is -13.4025
# Neutral mechanism log of rate constant for Amorphous Silica is -12.229
# Acid mechanism log of rate constant for forsterite is -6.85
# Neutral mechanism log of rate constant for forsterite is -10.64
# Magnesite line found at index 57: Magnesite            1.0e-10  specific_surface_area 0.1
# Modified line: Magnesite            9.8186517e-11  specific_surface_area 0.1
# Quartz line found at index 58: Quartz               1.008326e-10  specific_surface_area 0.1
# Modified line: Quartz               1e-10  specific_surface_area 0.1
# Amorphous_silica line found at index 59: Amorphous_silica     1.0009772e-10  specific_surface_area 0.1
# Modified line: Amorphous_silica     1e-10  specific_surface_area 0.1
# Forsterite line found at index 60: Forsterite           0.0019979810000000002  specific_surface_area 0.1
# Modified line: Forsterite           0.0030497867  specific_surface_area 0.1
# Magnesite line found at index 57: Magnesite            0.0010354988  specific_surface_area 0.1
# Modified line: Magnesite            0.00067610853  specific_surface_area 0.1
# Quartz line found at index 58: Quartz               1.0083955e-10  specific_surface_area 0.1
# Modified line: Quartz               1e-10  specific_surface_area 0.1
# Amorphous_silica line found at index 59: Amorphous_silica     1.0007926e-10  specific_surface_area 0.1
# Modified line: Amorphous_silica     1e-10  specific_surface_area 0.1
# Forsterite line found at index 61: Forsterite           0.0019979810000000002  specific_surface_area 0.1
# Modified line: Forsterite           0.0030497866000000003  specific_surface_area 0.1
# Found Equilibrium
# Pattern found on line 29: spatial_profile       6.0
# Pattern found on line 29: spatial_profile       0.34667800000000004
# Initial Concentration: 0.17416000151992822
# Final Concentration: 0.026737263574902147
# Percent Carbonation: 15.35212640190678%
# Time to reach equilibrium or end of experiment: 0.34667800000000004 hours
# Rate of change in Mg++ concentration: 0.0771242005048332 mol/kgw per hour

# %%
# Test and Run the 3 Interval Stitch Function at 50 degrees Celsius 

from Three_Interval_Stitch_Olivine_Modified import * 

Temp(50)

Model_Run, Magnesite_Volume_Fraction, Forsterite_Volume_Fraction = Time_Series('PestControl.ant')

Model_Run.to_csv('Olivine Model at 50°C.csv', index=False) 

Magnesium_Consumption_Rate, Carbonation_Percent = Magnesium_Rate(Model_Run)


print(Magnesium_Consumption_Rate)
print(Carbonation_Percent)
print(Magnesite_Volume_Fraction)

Volume_Fraction_50 = Magnesite_Volume_Fraction
Reaction_Rate_50 = Magnesium_Consumption_Rate
Carbonation_Percent_50 = Carbonation_Percent
Forsterite_Fraction_50 = Forsterite_Volume_Fraction
# Out:
# Acid depedence log of rate constant for magnesite is -6.1976
# Carbonate mechanism log of rate constant for magnesite is -4.3694
# Neutral mechanism log of rate constant for magnesite is -9.0167
# Neutral mechanism log of rate constant for Quartz is -12.1705
# Neutral mechanism log of rate constant for Amorphous Silica is -11.2192
# Acid mechanism log of rate constant for forsterite is -5.9392
# Neutral mechanism log of rate constant for forsterite is -9.5693
# Magnesite line found at index 57: Magnesite            9.8186517e-11  specific_surface_area 0.1
# Modified line: Magnesite            3.9709165e-11  specific_surface_area 0.1
# Quartz line found at index 58: Quartz               1e-10  specific_surface_area 0.1
# Modified line: Quartz               1.000001e-10  specific_surface_area 0.1
# Amorphous_silica line found at index 59: Amorphous_silica     1e-10  specific_surface_area 0.1
# Modified line: Amorphous_silica     1.0000003e-10  specific_surface_area 0.1
# Forsterite line found at index 60: Forsterite           0.0030497867  specific_surface_area 0.1
# Modified line: Forsterite           0.0030362112  specific_surface_area 0.1
# Magnesite line found at index 57: Magnesite            0.00067610853  specific_surface_area 0.1
# Modified line: Magnesite            0.0008449036  specific_surface_area 0.1
# Quartz line found at index 58: Quartz               1e-10  specific_surface_area 0.1
# Modified line: Quartz               1.000002e-10  specific_surface_area 0.1
# Amorphous_silica line found at index 59: Amorphous_silica     1e-10  specific_surface_area 0.1
# Modified line: Amorphous_silica     1.0000006e-10  specific_surface_area 0.1
# Forsterite line found at index 61: Forsterite           0.0030497866000000003  specific_surface_area 0.1
# Modified line: Forsterite           0.0030360971  specific_surface_area 0.1
# Found Equilibrium
# Pattern found on line 29: spatial_profile       0.1
# Pattern found on line 29: spatial_profile       0.11100030000000001
# Initial Concentration: 0.1741600015205757
# Final Concentration: 0.03106724106274463
# Percent Carbonation: 17.838333022220528%
# Time to reach equilibrium or end of experiment: 0.11100030000000001 hours
# Rate of change in Mg++ concentration: 0.2798842984274192 mol/kgw per hour

# %%
# Test and Run the 3 Interval Stitch Function at 100 degrees Celsius 

from Three_Interval_Stitch_Olivine_Modified import * 

Temp(100)

Model_Run, Magnesite_Volume_Fraction, Forsterite_Volume_Fraction = Time_Series('PestControl.ant')

Model_Run.to_csv('Olivine Model at 100°C.csv', index=False) 

Magnesium_Consumption_Rate, Carbonation_Percent = Magnesium_Rate(Model_Run)

print(Magnesium_Consumption_Rate)
print(Carbonation_Percent)
print(Magnesite_Volume_Fraction)

Volume_Fraction_100 = Magnesite_Volume_Fraction
Reaction_Rate_100 = Magnesium_Consumption_Rate
Carbonation_Percent_100 = Carbonation_Percent
Forsterite_Fraction_100 = Forsterite_Volume_Fraction
# Out:
# Acid depedence log of rate constant for magnesite is -5.8836
# Carbonate mechanism log of rate constant for magnesite is -3.0102
# Neutral mechanism log of rate constant for magnesite is -8.5078
# Neutral mechanism log of rate constant for Quartz is -10.2017
# Neutral mechanism log of rate constant for Amorphous Silica is -9.6057
# Acid mechanism log of rate constant for forsterite is -4.4838
# Neutral mechanism log of rate constant for forsterite is -7.8582
# Magnesite line found at index 57: Magnesite            3.9709165e-11  specific_surface_area 0.1
# Modified line: Magnesite            1.0e-10  specific_surface_area 0.1
# Quartz line found at index 58: Quartz               1.000001e-10  specific_surface_area 0.1
# Modified line: Quartz               1.008326e-10  specific_surface_area 0.1
# Amorphous_silica line found at index 59: Amorphous_silica     1.0000003e-10  specific_surface_area 0.1
# Modified line: Amorphous_silica     1.0009772e-10  specific_surface_area 0.1
# Forsterite line found at index 60: Forsterite           0.0030362112  specific_surface_area 0.1
# Modified line: Forsterite           0.0019979810000000002  specific_surface_area 0.1
# Magnesite line found at index 57: Magnesite            0.0008449036  specific_surface_area 0.1
# Modified line: Magnesite            0.0010354988  specific_surface_area 0.1
# Quartz line found at index 58: Quartz               1.000002e-10  specific_surface_area 0.1
# Modified line: Quartz               1.0083955e-10  specific_surface_area 0.1
# Amorphous_silica line found at index 59: Amorphous_silica     1.0000006e-10  specific_surface_area 0.1
# Modified line: Amorphous_silica     1.0007926e-10  specific_surface_area 0.1
# Forsterite line found at index 61: Forsterite           0.0030360971  specific_surface_area 0.1
# Modified line: Forsterite           0.0019979810000000002  specific_surface_area 0.1
# Found Equilibrium
# Pattern found on line 29: spatial_profile       6.0
# Pattern found on line 29: spatial_profile       6.16668
# Initial Concentration: 0.1741600020762399
# Final Concentration: 0.058905412406594714
# Percent Carbonation: 33.82258366120621%
# Time to reach equilibrium or end of experiment: 6.16668 hours
# Rate of change in Mg++ concentration: 0.009552208385638614 mol/kgw per hour

# %%
# Create the Three Bar Graphs for Volume Fraction, Reaction Rate, and Carbonation Percent 

import pandas as pd 

from Three_Interval_Stitch_Olivine_Modified import * 

# Compile the Data Together 
Volume_Fractions = [Volume_Fraction_25, Volume_Fraction_50, Volume_Fraction_100]
Reaction_Rates = [Reaction_Rate_25, Reaction_Rate_50, Reaction_Rate_100]
Carbonation_Percentages = [Carbonation_Percent_25, Carbonation_Percent_50, Carbonation_Percent_100]
Forsterite_Fractions = [Forsterite_Fraction_25, Forsterite_Fraction_50, Forsterite_Fraction_100]

# # Save Volume_Fractions to a CSV file
df_volume = pd.DataFrame({'Temperature (°C)': ['25°C', '50°C', '100°C'],
                           'Volume Fraction': Volume_Fractions})
df_volume.to_csv('Volume_Fractions.csv', index=False)

# # Save Reaction_Rates to a CSV file
df_reaction = pd.DataFrame({'Temperature (°C)': ['25°C', '50°C', '100°C'],
                            'Reaction Rate': Reaction_Rates})
df_reaction.to_csv('Reaction_Rates.csv', index=False)

# # Save Carbonation_Percentages to a CSV file
df_carbonation = pd.DataFrame({'Temperature (°C)': ['25°C', '50°C', '100°C'],
                               'Carbonation Percentage': Carbonation_Percentages})
df_carbonation.to_csv('Carbonation_Percentages.csv', index=False)

# Save Foresterite Volume_Fractions to a CSV file
df_volume = pd.DataFrame({'Temperature (°C)': ['25°C', '50°C', '100°C'],
                          'Volume Fraction': Forsterite_Fractions})
df_volume.to_csv('Forsterite_Fractions.csv', index=False)

# File paths for the CSV files
volume_fractions_file = 'Volume_Fractions.csv'
reaction_rates_file = 'Reaction_Rates.csv'
carbonation_percentages_file = 'Carbonation_Percentages.csv'
forsterite_fractions_file = 'Forsterite_Fractions.csv'

# Create the Volume Fraction Bar Graph for Magnesite

plot_bar_graph(volume_fractions_file, y_label='Magnesite Volume Fraction (m^3 mineral/m^3 porous medium)')

# Create the Reaction Rates Bar Graph

plot_bar_graph(reaction_rates_file, y_label=r'Reaction Rate (M hr$^{-1}$)')

# Create the Carbonation Percentage Bar Graph

plot_bar_graph(carbonation_percentages_file, y_label='Carbonation Percentage (%)')

# Create the Volume Fraction Bar Graph for Forsterite 

plot_bar_graph(forsterite_fractions_file, y_label='Forsterite Volume Fraction (m^3 mineral/m^3 porous medium)')
# Out:
# /Users/tszkipeterwei/Desktop/MEng/MEngProject/Setup/ModelingMineralCarbonation/CrunchtopeModel/3 Time Interval Model Olivine Case/Three_Interval_Stitch_Olivine_Modified.py:1327: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Temperature (°C)', y=data.columns[1], data=data, palette="viridis")
